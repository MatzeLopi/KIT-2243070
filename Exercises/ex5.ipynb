# %%
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp

from models import dmd, dmdc, errors

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scipy.integrate import solve_ivp   
def solve_vanderpol(t,l,c,a,b,x0):
    """
    Solves the Van der Pol oscillator ODE

    System equations:
        dx_1 = x[1] / p['L']
        dx_2 = (-x[0] - p['a'] * x[1] * (x[1]**2 - p['b'])) / p['C']

    Args:
        t (numpy.ndarray): time vector
        l (float): inductance
        c (float): capacity
        a (float): parameter a
        b (float): parameter b
        x0 (numpy.ndarray): initial state

    Function Outputs:
        t (numpy.ndarray): time vector
        x (numpy.ndarray): numerical solution
    """
    # Define the system ODE
    def vanderpol_ode(t,x,a,b,c,l):
        """
        Van der Pol oscillator ODE
        
        Args:
            t (float): time
            x (numpy.ndarray): state vector
            a (float): parameter a
            b (float): parameter b
            c (float): parameter c
            l (float): parameter l
        """
        dx1 = x[1] / l
        dx2 = (-x[0] - a * x[1] * (x[1]**2 - b)) / c
        return [dx1, dx2]

    # Solve the ODE
    sol = solve_ivp(vanderpol_ode, [t[0], t[-1]], x0, t_eval=t, args=(a,b,c,l))

    # Return the time vector and numerical solution
    return sol.t, sol.y


# Params for the Van der Pol oscillator
t = jnp.linspace(0, 20, 5001)
l = 1.0
c = 1.0
a = 1.0
b = 1.0
x0 = jnp.array([2.0, 0.0])

t, x = solve_vanderpol(t,l,c,a,b,x0)

x1 = x[0, :]
x2 = x[1, :]

plt.figure()
plt.plot(t, x1, label='x1')
plt.plot(t, x2, label='x2')
plt.xlabel('Time')
plt.ylabel('States')
plt.title('Van der Pol Oscillator')
plt.legend()
plt.show()

# %%
# Define Hankel matrix
hrow = 200
def hankel(hrow, x, t): 
    """ Create Hankel matrices from a time series x using delay embedding.
        For a data matrix x of shape (n, T), this function creates
        X   = [ x[:,0:m]; x[:,1:m+1]; ...; x[:,hrow-1:m+hrow-1] ]
        Xp  = [ x[:,1:m+1]; x[:,2:m+2]; ...; x[:,hrow:m+hrow] ]
        where m = T - hrow + 1.

    Args:
        hrow (int): number of delays (rows per block)
        x (jax.numpy.ndarray): data matrix of shape (n, T)
        t (jax.numpy.ndarray): time vector (length T)

    Returns:
        X (jax.numpy.ndarray): Hankel matrix of shape (n*hrow, m)
        Xp (jax.numpy.ndarray): time-shifted Hankel matrix of shape (n*hrow, m)
    """
    T = x.shape[1]
    m = T - hrow  # Use T - hrow so that both Hankel matrices have the same number of columns.
    X = jnp.concatenate([x[:, i:i+m] for i in range(hrow)], axis=0)
    Xp = jnp.concatenate([x[:, i+1:i+m+1] for i in range(hrow)], axis=0)
    return X, Xp

Xtd, Xtdp = hankel(hrow,x,t)
print(Xtd.shape, Xtdp.shape)
# Compute DMD
# a,b,phi,lam = dmd.dmdc(Xtd, Xtdp, r)  # Use corrected DMD function

a, phi, lam = dmd.dmd(Xtd, Xtdp, 3)

x0_hankel = Xtd[:, 0]  # shape is (n*hrow,)


sim = dmd.dmd_reconstruction(phi, lam, x0_hankel, jnp.arange(0, 5000))
x_recon = sim[:2, :]


plt.figure() 
plt.plot(x[0, :], x[1, :], 'k-', label='Original Trajectory') # original simulation 
plt.plot(x_recon[0, :].real, x_recon[1, :].real, 'r-', label='DMD Trajectory') 
plt.xlabel('x1') 
plt.ylabel('x2') 
plt.title('Trajectory Comparison in Original State Space') 
plt.legend() 
plt.show()
# Out:
# (400, 4801) (400, 4801)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 30
#      26 print(Xtd.shape, Xtdp.shape)
#      27 # Compute DMD
#      28 # a,b,phi,lam = dmd.dmdc(Xtd, Xtdp, r)  # Use corrected DMD function
# ---> 30 a, phi, lam = dmd.dmd(Xtd, Xtdp, 3)
#      32 x0_hankel = Xtd[:, 0]  # shape is (n*hrow,)
#      35 sim = dmd.dmd_reconstruction(phi, lam, x0_hankel, jnp.arange(0, 5000))
#
# AttributeError: module 'models.dmd' has no attribute 'dmd'

# %%
display(x.shape)
# Out:
# (2, 5001)

# %%
x_ = x[:-1]     
x_prime = x[1:]  

display(x_.shape)
display(x_prime.shape)
display(x0.shape)
# Out:
# (1, 5001)
# (1, 5001)
# (2,)

# %%
r, a, phi, lam = dmd.optimize(x_,x_prime, t,(1,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 r, a, phi, lam = dmd.optimize(x_,x_prime, t,(1,20))
#
# File ~/WS_all/dbm/Exercises/models/dmd.py:109, in optimize(x, x_prime, t, r_range)
#     106 a_tilde, phi, lambda_ = fit(x, x_prime, r)
#     108 x_recon = simulate(phi, lambda_, x_0, t[:-1]).T
# --> 109 error = _mean_absolute_error(x, x_recon)
#     111 if error < best_error:
#     112     best_error = error
#
#     [... skipping hidden 13 frame]
#
# File ~/WS_all/dbm/Exercises/models/errors.py:30, in _mean_absolute_error(y_true, y_pred)
#      19 @jax.jit
#      20 def _mean_absolute_error(y_true: jax.Array, y_pred: jax.Array) -> jax.Array:
#      21     """Mean Absolute Error
#      22
#      23     Args:
#    (...)     28         jax.Array: Mean Absolute Error
#      29     """
# ---> 30     return jnp.mean(jnp.abs(y_true - y_pred))
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     178   raise NotImplementedError(f"where argument of {self}")
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/ufuncs.py:1544, in subtract(x, y)
#    1517 @binary_ufunc(identity=None, at=_subtract_at)
#    1518 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1519   """Subtract two arrays element-wise.
#    1520
#    1521   JAX implementation of :obj:`numpy.subtract`. This is a universal function,
#    (...)   1542     Array([-10,  -9,  -8,  -7], dtype=int32)
#    1543   """
# -> 1544   return lax.sub(*promote_args("subtract", x, y))
#
#     [... skipping hidden 9 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/lax/lax.py:132, in _try_broadcast_shapes(name, *shapes)
#     130       result_shape.append(non_1s[0])
#     131     else:
# --> 132       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     133                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     134 return tuple(result_shape)
#
# TypeError: sub got incompatible shapes for broadcasting: (1, 5001), (1, 5000).

# %%
result = dmd.simulate(phi, lam,x0,t)
result = result.real
display(result.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result = dmd.simulate(phi, lam,x0,t)
#       2 result = result.real
#       3 display(result.shape)
#
#     [... skipping hidden 13 frame]
#
# File ~/WS_all/dbm/Exercises/models/dmd.py:57, in simulate(phi, lambda_, x0, timesteps)
#      45 """Reconstruct the time dynamics of the DMD model.
#      46
#      47 Args:
#    (...)     54     jax.Array: Reconstructed state trajectory (T+1 x n), with the first row equal to x0.
#      55 """
#      56 # Project initial state onto the reduced coordinates.
# ---> 57 z0 = jnp.linalg.pinv(phi) @ x0  # shape: (r,)
#      59 # Define the reduced dynamics operator as a diagonal matrix from the eigenvalues.
#      60 A_dmd = jnp.diag(lambda_)  # shape: (r x r)
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 14 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/tensor_contractions.py:243, in matmul(a, b, precision, preferred_element_type)
#     241 a = lax.squeeze(a, tuple(a_squeeze))
#     242 b = lax.squeeze(b, tuple(b_squeeze))
# --> 243 out = lax.dot_general(
#     244   a, b, (((np.ndim(a) - 1,), (np.ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#     245   precision=precision, preferred_element_type=preferred_element_type)
#     246 result = lax.transpose(out, perm)
#     247 return lax_internal._convert_element_type(result, preferred_element_type, output_weak_type)
#
#     [... skipping hidden 8 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/lax/lax.py:4647, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type, out_sharding)
#    4644 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    4645   msg = ("dot_general requires contracting dimensions to have the same "
#    4646          "shape, got {} and {}.")
# -> 4647   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    4649 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (5001,) and (2,).

# %%
display(errors._mean_absolute_error(x, result))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 display(errors._mean_absolute_error(x, result))
#
#     [... skipping hidden 13 frame]
#
# File ~/WS_all/dbm/Exercises/models/errors.py:30, in _mean_absolute_error(y_true, y_pred)
#      19 @jax.jit
#      20 def _mean_absolute_error(y_true: jax.Array, y_pred: jax.Array) -> jax.Array:
#      21     """Mean Absolute Error
#      22
#      23     Args:
#    (...)     28         jax.Array: Mean Absolute Error
#      29     """
# ---> 30     return jnp.mean(jnp.abs(y_true - y_pred))
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     178   raise NotImplementedError(f"where argument of {self}")
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/numpy/ufuncs.py:1544, in subtract(x, y)
#    1517 @binary_ufunc(identity=None, at=_subtract_at)
#    1518 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1519   """Subtract two arrays element-wise.
#    1520
#    1521   JAX implementation of :obj:`numpy.subtract`. This is a universal function,
#    (...)   1542     Array([-10,  -9,  -8,  -7], dtype=int32)
#    1543   """
# -> 1544   return lax.sub(*promote_args("subtract", x, y))
#
#     [... skipping hidden 9 frame]
#
# File ~/miniconda3/envs/python3.13/lib/python3.13/site-packages/jax/_src/lax/lax.py:132, in _try_broadcast_shapes(name, *shapes)
#     130       result_shape.append(non_1s[0])
#     131     else:
# --> 132       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     133                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     134 return tuple(result_shape)
#
# TypeError: sub got incompatible shapes for broadcasting: (2, 5001), (5001, 5001).
